# %%
"""
map_data_clean.ipynb

File used to clean up the map/census data from 
https://chronicdata.cdc.gov/500-Cities-Places/PLACES-Local-Data-for-Better-Health-Place-Data-202/eav7-hnsx/data

This dataset will be used to create map visualizations
"""
# Out:
# '\nmap_data_clean.ipynb\n\nFile used to clean up the map/census data from \nhttps://chronicdata.cdc.gov/500-Cities-Places/PLACES-Local-Data-for-Better-Health-Place-Data-202/eav7-hnsx/data\n\nThis dataset will be used to create map visualizations\n'

# %%
# Importing statements

import pandas as pd
import math

# %%
# Importing raw dataset

df = pd.read_csv('places_raw.csv')

# %%
# Preview dataset

print(df.columns)
df.head()
# Out:
# Index(['Year', 'StateAbbr', 'StateDesc', 'LocationName', 'DataSource',
#        'Category', 'Measure', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'TotalPopulation',
#        'Geolocation', 'LocationID', 'CategoryID', 'MeasureId',
#        'DataValueTypeID', 'Short_Question_Text'],
#       dtype='object')
#    Year StateAbbr StateDesc LocationName DataSource         Category  \
# 0  2020        AL   Alabama       Hatton      BRFSS       Prevention
# 1  2020        AL   Alabama       Lester      BRFSS  Health Outcomes
# 2  2020        AL   Alabama   Loachapoka      BRFSS  Health Outcomes
# 3  2020        AL   Alabama     Lockhart      BRFSS  Health Outcomes
# 4  2020        AL   Alabama  Mount Olive      BRFSS  Health Outcomes
#
#                                            Measure Data_Value_Unit  \
# 0     Mammography use among women aged 50-74 years               %
# 1           Arthritis among adults aged >=18 years               %
# 2          Depression among adults aged >=18 years               %
# 3              Stroke among adults aged >=18 years               %
# 4  Diagnosed diabetes among adults aged >=18 years               %
#
#            Data_Value_Type  Data_Value  ... Data_Value_Footnote  \
# 0         Crude prevalence        76.0  ...                 NaN
# 1         Crude prevalence        29.5  ...                 NaN
# 2         Crude prevalence        22.4  ...                 NaN
# 3  Age-adjusted prevalence         4.1  ...                 NaN
# 4         Crude prevalence        10.9  ...                 NaN
#
#   Low_Confidence_Limit  High_Confidence_Limit  TotalPopulation  \
# 0                 71.5                   80.0              261
# 1                 27.8                   31.3              111
# 2                 21.1                   23.7              180
# 3                  3.8                    4.4              516
# 4                 10.2                   11.6              371
#
#                         Geolocation LocationID  CategoryID   MeasureId  \
# 0  POINT (-87.41355648 34.56106698)     133544     PREVENT    MAMMOUSE
# 1  POINT (-87.15152276 34.98770736)     142352     HLTHOUT   ARTHRITIS
# 2  POINT (-85.59478461 32.60493606)     143744     HLTHOUT  DEPRESSION
# 3  POINT (-86.35050395 31.01276612)     143816     HLTHOUT      STROKE
# 4  POINT (-86.13338912 33.07643049)     152320     HLTHOUT    DIABETES
#
#   DataValueTypeID Short_Question_Text
# 0          CrdPrv         Mammography
# 1          CrdPrv           Arthritis
# 2          CrdPrv          Depression
# 3       AgeAdjPrv              Stroke
# 4          CrdPrv            Diabetes
#
# [5 rows x 21 columns]

# %%
# Column values exploration

print('Unique Data_Value_Unit: ', df.Data_Value_Unit.unique(), '\n')
print('Unique StateDesc: ', df.StateDesc.unique(), '\n')
print('Unique Year: ', df.Year.unique(), '\n')
print('Unique Short_Question_Text: ', df.Short_Question_Text.unique(), '\n')
print('Unique Measure: ', df.Measure.unique(), '\n')
# Out:
# Unique Data_Value_Unit:  ['%']
#
# Unique StateDesc:  ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'District of Columbia' 'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma'
#  'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina' 'South Dakota'
#  'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia' 'Washington'
#  'West Virginia' 'Wisconsin' 'Wyoming']
#
# Unique Year:  [2020 2019]
#
# Unique Short_Question_Text:  ['Mammography' 'Arthritis' 'Depression' 'Stroke' 'Diabetes' 'Obesity'
#  'Current Asthma' 'All Teeth Lost' 'Binge Drinking' 'Dental Visit' 'COPD'
#  'Health Insurance' 'Core preventive services for older men'
#  'Physical Inactivity' 'Current Smoking' 'Physical Health'
#  'Taking BP Medication' 'Colorectal Cancer Screening'
#  'Coronary Heart Disease' 'Sleep <7 hours' 'Annual Checkup'
#  'Core preventive services for older women' 'General Health'
#  'Cholesterol Screening' 'Mental Health' 'Cancer (except skin)'
#  'High Blood Pressure' 'Chronic Kidney Disease' 'High Cholesterol'
#  'Cervical Cancer Screening']
#
# Unique Measure:  ['Mammography use among women aged 50-74 years'
#  'Arthritis among adults aged >=18 years'
#  'Depression among adults aged >=18 years'
#  'Stroke among adults aged >=18 years'
#  'Diagnosed diabetes among adults aged >=18 years'
#  'Obesity among adults aged >=18 years'
#  'Current asthma among adults aged >=18 years'
#  'All teeth lost among adults aged >=65 years'
#  'Binge drinking among adults aged >=18 years'
#  'Visits to dentist or dental clinic among adults aged >=18 years'
#  'Chronic obstructive pulmonary disease among adults aged >=18 years'
#  'Current lack of health insurance among adults aged 18-64 years'
#  'Older adult men aged >=65 years who are up to date on a core set of clinical preventive services: Flu shot past year, PPV shot ever, Colorectal cancer screening'
#  'No leisure-time physical activity among adults aged >=18 years'
#  'Current smoking among adults aged >=18 years'
#  'Physical health not good for >=14 days among adults aged >=18 years'
#  'Taking medicine for high blood pressure control among adults aged >=18 years with high blood pressure'
#  'Fecal occult blood test, sigmoidoscopy, or colonoscopy among adults aged 50-75 years'
#  'Coronary heart disease among adults aged >=18 years'
#  'Sleeping less than 7 hours among adults aged >=18 years'
#  'Visits to doctor for routine checkup within the past year among adults aged >=18 years'
#  'Older adult women aged >=65 years who are up to date on a core set of clinical preventive services: Flu shot past year, PPV shot ever, Colorectal cancer screening, and Mammogram past 2 years'
#  'Fair or poor self-rated health status among adults aged >=18 years'
#  'Cholesterol screening among adults aged >=18 years'
#  'Mental health not good for >=14 days among adults aged >=18 years'
#  'Cancer (excluding skin cancer) among adults aged >=18 years'
#  'High blood pressure among adults aged >=18 years'
#  'Chronic kidney disease among adults aged >=18 years'
#  'High cholesterol among adults aged >=18 years who have been screened in the past 5 years'
#  'Cervical cancer screening among adult women aged 21-65 years']

# %%
# How many from 2020 vs 2019

print(len(df[df['Year'] == 2020]))
print(len(df[df['Year'] == 2019]))
# Out:
# 1480958
# 223544

# %%
# Splitting up dataset by years

df_2020 = df[df['Year'] == 2020]
df_2019 = df[df['Year'] == 2019]

# %%
state_codes = {
    'WA': '53', 'DE': '10', 'DC': '11', 'WI': '55', 'WV': '54', 'HI': '15',
    'FL': '12', 'WY': '56', 'PR': '72', 'NJ': '34', 'NM': '35', 'TX': '48',
    'LA': '22', 'NC': '37', 'ND': '38', 'NE': '31', 'TN': '47', 'NY': '36',
    'PA': '42', 'AK': '02', 'NV': '32', 'NH': '33', 'VA': '51', 'CO': '08',
    'CA': '06', 'AL': '01', 'AR': '05', 'VT': '50', 'IL': '17', 'GA': '13',
    'IN': '18', 'IA': '19', 'MA': '25', 'AZ': '04', 'ID': '16', 'CT': '09',
    'ME': '23', 'MD': '24', 'OK': '40', 'OH': '39', 'UT': '49', 'MO': '29',
    'MN': '27', 'MI': '26', 'RI': '44', 'KS': '20', 'MT': '30', 'MS': '28',
    'SC': '45', 'KY': '21', 'OR': '41', 'SD': '46'
}

df_2020['FIP'] = df_2020.apply(lambda row: state_codes[row.StateAbbr], axis=1)
df_2019['FIP'] = df_2019.apply(lambda row: state_codes[row.StateAbbr], axis=1)
# Out:
# /var/folders/mp/rh6p883n7g5b5g8rz3p4104h0000gn/T/ipykernel_27255/1165526422.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['FIP'] = df_2020.apply(lambda row: state_codes[row.StateAbbr], axis=1)
# /var/folders/mp/rh6p883n7g5b5g8rz3p4104h0000gn/T/ipykernel_27255/1165526422.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['FIP'] = df_2019.apply(lambda row: state_codes[row.StateAbbr], axis=1)

# %%
df_2020.head()
# Out:
#    Year StateAbbr StateDesc LocationName DataSource         Category  \
# 0  2020        AL   Alabama       Hatton      BRFSS       Prevention
# 1  2020        AL   Alabama       Lester      BRFSS  Health Outcomes
# 2  2020        AL   Alabama   Loachapoka      BRFSS  Health Outcomes
# 3  2020        AL   Alabama     Lockhart      BRFSS  Health Outcomes
# 4  2020        AL   Alabama  Mount Olive      BRFSS  Health Outcomes
#
#                                            Measure Data_Value_Unit  \
# 0     Mammography use among women aged 50-74 years               %
# 1           Arthritis among adults aged >=18 years               %
# 2          Depression among adults aged >=18 years               %
# 3              Stroke among adults aged >=18 years               %
# 4  Diagnosed diabetes among adults aged >=18 years               %
#
#            Data_Value_Type  Data_Value  ... Low_Confidence_Limit  \
# 0         Crude prevalence        76.0  ...                 71.5
# 1         Crude prevalence        29.5  ...                 27.8
# 2         Crude prevalence        22.4  ...                 21.1
# 3  Age-adjusted prevalence         4.1  ...                  3.8
# 4         Crude prevalence        10.9  ...                 10.2
#
#   High_Confidence_Limit  TotalPopulation                       Geolocation  \
# 0                  80.0              261  POINT (-87.41355648 34.56106698)
# 1                  31.3              111  POINT (-87.15152276 34.98770736)
# 2                  23.7              180  POINT (-85.59478461 32.60493606)
# 3                   4.4              516  POINT (-86.35050395 31.01276612)
# 4                  11.6              371  POINT (-86.13338912 33.07643049)
#
#   LocationID CategoryID   MeasureId DataValueTypeID Short_Question_Text FIP
# 0     133544    PREVENT    MAMMOUSE          CrdPrv         Mammography  01
# 1     142352    HLTHOUT   ARTHRITIS          CrdPrv           Arthritis  01
# 2     143744    HLTHOUT  DEPRESSION          CrdPrv          Depression  01
# 3     143816    HLTHOUT      STROKE       AgeAdjPrv              Stroke  01
# 4     152320    HLTHOUT    DIABETES          CrdPrv            Diabetes  01
#
# [5 rows x 22 columns]

# %%
# Removing unnecessary columns from datasets

desired_cols = ['Year', 'StateDesc', 'LocationName', 'Measure', 'Category', 'Data_Value',
                'TotalPopulation', 'Geolocation', 'Short_Question_Text', 'FIP', 'StateAbbr']
df_2020 = df_2020[desired_cols]
df_2019 = df_2019[desired_cols]

df_2020.head()
# Out:
#    Year StateDesc LocationName  \
# 0  2020   Alabama       Hatton
# 1  2020   Alabama       Lester
# 2  2020   Alabama   Loachapoka
# 3  2020   Alabama     Lockhart
# 4  2020   Alabama  Mount Olive
#
#                                            Measure         Category  \
# 0     Mammography use among women aged 50-74 years       Prevention
# 1           Arthritis among adults aged >=18 years  Health Outcomes
# 2          Depression among adults aged >=18 years  Health Outcomes
# 3              Stroke among adults aged >=18 years  Health Outcomes
# 4  Diagnosed diabetes among adults aged >=18 years  Health Outcomes
#
#    Data_Value TotalPopulation                       Geolocation  \
# 0        76.0             261  POINT (-87.41355648 34.56106698)
# 1        29.5             111  POINT (-87.15152276 34.98770736)
# 2        22.4             180  POINT (-85.59478461 32.60493606)
# 3         4.1             516  POINT (-86.35050395 31.01276612)
# 4        10.9             371  POINT (-86.13338912 33.07643049)
#
#   Short_Question_Text FIP StateAbbr
# 0         Mammography  01        AL
# 1           Arthritis  01        AL
# 2          Depression  01        AL
# 3              Stroke  01        AL
# 4            Diabetes  01        AL

# %%
# Removing NaN from Data_Value and TotalPopulatioin columns

df_2020=df_2020.dropna(subset=['Data_Value','TotalPopulation'])

# %%
# Removing commas from TotalPopulation column

df_2020['TotalPopulation'] = df_2020['TotalPopulation'].map(lambda x: x.replace(',', ''))

# %%
# Creating a TotalNumber column representing the actual amount of people instead of a percentage

df_2020['TotalNumber'] = df_2020.apply(lambda row: math.ceil((row.Data_Value / 100) * int(row.TotalPopulation)), axis=1)

# %%
df_2020.head()
# Out:
#    Year StateDesc LocationName  \
# 0  2020   Alabama       Hatton
# 1  2020   Alabama       Lester
# 2  2020   Alabama   Loachapoka
# 3  2020   Alabama     Lockhart
# 4  2020   Alabama  Mount Olive
#
#                                            Measure         Category  \
# 0     Mammography use among women aged 50-74 years       Prevention
# 1           Arthritis among adults aged >=18 years  Health Outcomes
# 2          Depression among adults aged >=18 years  Health Outcomes
# 3              Stroke among adults aged >=18 years  Health Outcomes
# 4  Diagnosed diabetes among adults aged >=18 years  Health Outcomes
#
#    Data_Value TotalPopulation                       Geolocation  \
# 0        76.0             261  POINT (-87.41355648 34.56106698)
# 1        29.5             111  POINT (-87.15152276 34.98770736)
# 2        22.4             180  POINT (-85.59478461 32.60493606)
# 3         4.1             516  POINT (-86.35050395 31.01276612)
# 4        10.9             371  POINT (-86.13338912 33.07643049)
#
#   Short_Question_Text FIP StateAbbr  TotalNumber
# 0         Mammography  01        AL          199
# 1           Arthritis  01        AL           33
# 2          Depression  01        AL           41
# 3              Stroke  01        AL           22
# 4            Diabetes  01        AL           41

# %%
# Creating a grouped dataframe that sums the TotalNumber column in terms of states and measures

sum_2020 = df_2020.groupby(['StateDesc', 'Short_Question_Text', 'Measure', 'StateAbbr'])['TotalNumber'].sum().reset_index()

# %%
sum_2020.head()
# Out:
#   StateDesc Short_Question_Text  \
# 0   Alabama      All Teeth Lost
# 1   Alabama      Annual Checkup
# 2   Alabama           Arthritis
# 3   Alabama      Binge Drinking
# 4   Alabama                COPD
#
#                                              Measure StateAbbr  TotalNumber
# 0        All teeth lost among adults aged >=65 years        AL      1073619
# 1  Visits to doctor for routine checkup within th...        AL      4736982
# 2             Arthritis among adults aged >=18 years        AL      1819705
# 3        Binge drinking among adults aged >=18 years        AL       907088
# 4  Chronic obstructive pulmonary disease among ad...        AL       503812

# %%
# pulls the longitude from the Geolocation string
def pull_lon(x):
    str1 = x.split('(', 1)[1]
    str1 = str1.replace(')', '')
    return float(str1.split(' ', 1)[0])

# pulls the latitude from the Geolocation string
def pull_lat(x):
    str1 = x.split('(', 1)[1]
    str1 = str1.replace(')', '')
    return float(str1.split(' ', 1)[1])

# %%
# creating a latitude and longitude column

df_2020['Longitude'] = df_2020.apply(lambda row: pull_lon(row.Geolocation), axis=1)
df_2020['Latitude'] = df_2020.apply(lambda row: pull_lat(row.Geolocation), axis=1)

# %%
df_2020.head()
# Out:
#    Year StateDesc LocationName  \
# 0  2020   Alabama       Hatton
# 1  2020   Alabama       Lester
# 2  2020   Alabama   Loachapoka
# 3  2020   Alabama     Lockhart
# 4  2020   Alabama  Mount Olive
#
#                                            Measure         Category  \
# 0     Mammography use among women aged 50-74 years       Prevention
# 1           Arthritis among adults aged >=18 years  Health Outcomes
# 2          Depression among adults aged >=18 years  Health Outcomes
# 3              Stroke among adults aged >=18 years  Health Outcomes
# 4  Diagnosed diabetes among adults aged >=18 years  Health Outcomes
#
#    Data_Value TotalPopulation                       Geolocation  \
# 0        76.0             261  POINT (-87.41355648 34.56106698)
# 1        29.5             111  POINT (-87.15152276 34.98770736)
# 2        22.4             180  POINT (-85.59478461 32.60493606)
# 3         4.1             516  POINT (-86.35050395 31.01276612)
# 4        10.9             371  POINT (-86.13338912 33.07643049)
#
#   Short_Question_Text FIP StateAbbr  TotalNumber  Longitude   Latitude
# 0         Mammography  01        AL          199 -87.413556  34.561067
# 1           Arthritis  01        AL           33 -87.151523  34.987707
# 2          Depression  01        AL           41 -85.594785  32.604936
# 3              Stroke  01        AL           22 -86.350504  31.012766
# 4            Diabetes  01        AL           41 -86.133389  33.076430

# %%
popdf = pd.read_csv('populations.csv')

popdf.head()
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  ESTIMATESBASE2020  \
# 0      10      0        0      0     United States          331449281
# 1      20      1        0      0  Northeast Region           57609148
# 2      20      2        0      0    Midwest Region           68985454
# 3      20      3        0      0      South Region          126266107
# 4      20      4        0      0       West Region           78588572
#
#    POPESTIMATE2020  POPESTIMATE2021  NPOPCHG_2020  NPOPCHG_2021  ...  \
# 0        331501080        331893745         51799        392665  ...
# 1         57525633         57159838        -83515       -365795  ...
# 2         68935174         68841444        -50280        -93730  ...
# 3        126409007        127225329        142900        816322  ...
# 4         78631266         78667134         42694         35868  ...
#
#    NETMIG2020  NETMIG2021  RESIDUAL2020  RESIDUAL2021  RBIRTH2021  RDEATH2021  \
# 0       12247      244622             0             0   10.798957   10.352637
# 1      -79429     -333592         -1024         -1151    9.950554   10.492070
# 2      -47266      -85268          -718          5156   10.860566   11.058248
# 3      134454      770076           528         -3385   11.168835   10.777476
# 4        4488     -106594          1214          -620   10.767153    8.947910
#
#    RNATURALINC2021  RINTERNATIONALMIG2021  RDOMESTICMIG2021  RNETMIG2021
# 0         0.446319               0.737485          0.000000     0.737485
# 1        -0.541516               0.977386         -6.794897    -5.817511
# 2        -0.197682               0.549222         -1.786994    -1.237772
# 3         0.391359               0.886268          5.186064     6.072332
# 4         1.819243               0.487570         -1.842880    -1.355309
#
# [5 rows x 30 columns]

# %%
popdf = popdf[popdf['STATE'] != 0]
popdf = popdf[['NAME', 'ESTIMATESBASE2020']]



popdf.rename(columns={'NAME': 'StateDesc'}, inplace=True)

popdf.head()
# Out:
#     StateDesc  ESTIMATESBASE2020
# 5     Alabama            5024279
# 6      Alaska             733391
# 7     Arizona            7151502
# 8    Arkansas            3011524
# 9  California           39538223

# %%
df_cd = pd.merge(sum_2020, popdf, how='outer', on='StateDesc')

# %%
df_cd.head()
# Out:
#   StateDesc Short_Question_Text  \
# 0   Alabama      All Teeth Lost
# 1   Alabama      Annual Checkup
# 2   Alabama           Arthritis
# 3   Alabama      Binge Drinking
# 4   Alabama                COPD
#
#                                              Measure StateAbbr  TotalNumber  \
# 0        All teeth lost among adults aged >=65 years        AL    1073619.0
# 1  Visits to doctor for routine checkup within th...        AL    4736982.0
# 2             Arthritis among adults aged >=18 years        AL    1819705.0
# 3        Binge drinking among adults aged >=18 years        AL     907088.0
# 4  Chronic obstructive pulmonary disease among ad...        AL     503812.0
#
#    ESTIMATESBASE2020
# 0            5024279
# 1            5024279
# 2            5024279
# 3            5024279
# 4            5024279

# %%
# Saving the sum_2020 to a csv

df_cd.to_csv('grouped_2020.csv')

# %%
# Saving the df_2020 to a csv

df_2020.to_csv('measures_2020.csv')
